# %%
import acquire

# %%
acquire
# Out:
# <module 'acquire' from '/Users/josephburton/Documents/ds_methodologies_exercises/Classification/acquire.py'>

# %%
titanic_df = acquire.get_titanic_data()
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
iris_df = acquire.get_iris_data()
iris_df.head()
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
# 3               4           4.6          3.1           1.5          0.2
# 4               5           5.0          3.6           1.4          0.2
#
#    species_id species_name
# 0           1       setosa
# 1           1       setosa
# 2           1       setosa
# 3           1       setosa
# 4           1       setosa

# %% [markdown]
# ## Use the function defined in acquire.py to load the iris data.
# - Drop the species_id and measurement_id columns.

# %%
iris_df = iris_df.drop(['species_id', 'measurement_id'], axis=1)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species_name
# 0           5.1          3.5           1.4          0.2       setosa
# 1           4.9          3.0           1.4          0.2       setosa
# 2           4.7          3.2           1.3          0.2       setosa
# 3           4.6          3.1           1.5          0.2       setosa
# 4           5.0          3.6           1.4          0.2       setosa

# %% [markdown]
# - Rename the species_name column to just species.

# %%
iris_df = iris_df.rename(columns={'species_name': 'species'})
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# - Encode the species name using a sklearn label encoder. Research the inverse_transform method of the label encoder. How might this be useful?
# -- The inverse_transform method would be useful in simply stating the value of each assigned number caused by originally coding the feature.

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(iris_df.species)
# Out:
# LabelEncoder()

# %%
iris_df.species = encoder.transform(iris_df.species)

# %%
iris_df.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 112           6.8          3.0           5.5          2.1        2
# 92            5.8          2.6           4.0          1.2        1
# 139           6.9          3.1           5.4          2.1        2
# 41            4.5          2.3           1.3          0.3        0
# 95            5.7          3.0           4.2          1.2        1
# 53            5.5          2.3           4.0          1.3        1
# 89            5.5          2.5           4.0          1.3        1
# 10            5.4          3.7           1.5          0.2        0
# 149           5.9          3.0           5.1          1.8        2
# 137           6.4          3.1           5.5          1.8        2

# %% [markdown]
# - Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def drop_species_id(df):
    return df.drop(columns='species_id')

# %%
def drop_measurement_id(df):
    return df.drop(columns='measurement_id')

# %%
def rename_speciesname(df):
    return df.rename(columns={'species_name': 'species'})

# %%
def encode_species(df):
    encoder = LabelEncoder()
    encoder.fit(df.species)
    return df.assign(species=encoder.transform(df.species))

# %%
def prep_iris_data(df):
    return df.pipe(drop_species_id)\
        .pipe(drop_measurement_id)\
        .pipe(rename_speciesname)\
        .pipe(encode_species)

# %%
from acquire import get_iris_data
prep_iris_data(get_iris_data())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# 5             5.4          3.9           1.7          0.4        0
# 6             4.6          3.4           1.4          0.3        0
# 7             5.0          3.4           1.5          0.2        0
# 8             4.4          2.9           1.4          0.2        0
# 9             4.9          3.1           1.5          0.1        0
# 10            5.4          3.7           1.5          0.2        0
# 11            4.8          3.4           1.6          0.2        0
# 12            4.8          3.0           1.4          0.1        0
# ...

# %% [markdown]
# ## Use the function you defined in acquire.py to load the titanic data set.

# %%
titanic_df = acquire.get_titanic_data()
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
titanic_df.isnull().sum()
# Out:
# passenger_id      0
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          2
# class             0
# deck            688
# embark_town       2
# alone             0
# dtype: int64

# %% [markdown]
# # Handle the missing values in the embark_town and embarked columns.

# %%
titanic_df.embarked.fillna('O', inplace=True)

# %%
titanic_df.embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# O      2
# Name: embarked, dtype: int64

# %%
titanic_df.embark_town.fillna('Other', inplace=True)

# %%
titanic_df.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Other            2
# Name: embark_town, dtype: int64

# %% [markdown]
# - Remove the deck column.

# %%
titanic_df = titanic_df.drop(['deck'], axis=1)
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  embark_town  alone
# 0        S  Third  Southampton      0
# 1        C  First    Cherbourg      0
# 2        S  Third  Southampton      1
# 3        S  First  Southampton      0
# 4        S  Third  Southampton      1

# %% [markdown]
# - Use a label encoder to transform the embarked column.

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(titanic_df.embarked)
# Out:
# LabelEncoder()

# %%
titanic_df.embarked = encoder.transform(titanic_df.embarked)
titanic_df.head(10)
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# 5             5         0       3    male   NaN      0      0   8.4583
# 6             6         0       1    male  54.0      0      0  51.8625
# 7             7         0       3    male   2.0      3      1  21.0750
# 8             8         1       3  female  27.0      0      2  11.1333
# 9             9         1       2  female  14.0      1      0  30.0708
#
#    embarked   class  embark_town  alone
# 0         3   Third  Southampton      0
# 1         0   First    Cherbourg      0
# 2         3   Third  Southampton      1
# ...

# %% [markdown]
# - Scale the age and fare columns using a min max scaler. Why might this be beneficial? When might you not want to do this?

# %%
min_age = titanic_df.age.min()
min_age
# Out:
# 0.42

# %%
max_age = titanic_df.age.max()
max_age
# Out:
# 80.0

# %%
titanic_df.age = (titanic_df.age - min_age) / (max_age - min_age)
titanic_df.head(10)
# Out:
#    passenger_id  survived  pclass     sex       age  sibsp  parch     fare  \
# 0             0         0       3    male -0.001870      1      0   7.2500
# 1             1         1       1  female  0.000656      1      0  71.2833
# 2             2         1       3  female -0.001239      0      0   7.9250
# 3             3         1       1  female  0.000183      1      0  53.1000
# 4             4         0       3    male  0.000183      0      0   8.0500
# 5             5         0       3    male       NaN      0      0   8.4583
# 6             6         0       1    male  0.003183      0      0  51.8625
# 7             7         0       3    male -0.005028      3      1  21.0750
# 8             8         1       3  female -0.001081      0      2  11.1333
# 9             9         1       2  female -0.003133      1      0  30.0708
#
#    embarked   class  embark_town  alone
# 0         3   Third  Southampton      0
# 1         0   First    Cherbourg      0
# ...

# %%
min_fare = titanic_df.fare.min()
min_fare
# Out:
# 0.0

# %%
max_fare = titanic_df.fare.max()
max_fare
# Out:
# 512.3292

# %%
titanic_df.fare = (titanic_df.fare - min_fare) / (max_fare - min_fare)
titanic_df.head(10)
# Out:
#    passenger_id  survived  pclass     sex       age  sibsp  parch      fare  \
# 0             0         0       3    male -0.001870      1      0  0.014151
# 1             1         1       1  female  0.000656      1      0  0.139136
# 2             2         1       3  female -0.001239      0      0  0.015469
# 3             3         1       1  female  0.000183      1      0  0.103644
# 4             4         0       3    male  0.000183      0      0  0.015713
# 5             5         0       3    male       NaN      0      0  0.016510
# 6             6         0       1    male  0.003183      0      0  0.101229
# 7             7         0       3    male -0.005028      3      1  0.041136
# 8             8         1       3  female -0.001081      0      2  0.021731
# 9             9         1       2  female -0.003133      1      0  0.058694
#
#    embarked   class  embark_town  alone
# 0         3   Third  Southampton      0
# 1         0   First    Cherbourg      0
# ...

# %% [markdown]
# - Create a function named prep_titanic that accepts the untransformed titanic data, and returns the data with the transformations above applied.

# %%
def handle_missing_values(df):
    return df.assign(
        embarked=df.embarked.fillna('O'),
        embark_town=df.embark_town.fillna('Other')
    )

# %%
def remove_deck(df):
    return df.drop(columns='deck')

# %%
def encode_embarked(df):
    encoder = LabelEncoder()
    encoder.fit(df.embarked)
    return df.assign(embarked=encoder.transform(df.embarked))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
def age_fare_normalizer(df):
    scaler = MinMaxScaler()
    scaler.fit(df[['fare', 'age']])
    df[['fare', 'age']] = scaler.transform(df[['fare', 'age']])
    return df

# %%
def prep_titanic_data(df):
    return df.pipe(handle_missing_values)\
        .pipe(remove_deck)\
        .pipe(encode_embarked)\
        .pipe(age_fare_normalizer)

# %%
from acquire import get_titanic_data
titanic_prep = prep_titanic_data(get_titanic_data())
titanic_prep.head()
# Out:
#    passenger_id  survived  pclass     sex       age  sibsp  parch      fare  \
# 0             0         0       3    male  0.271174      1      0  0.014151
# 1             1         1       1  female  0.472229      1      0  0.139136
# 2             2         1       3  female  0.321438      0      0  0.015469
# 3             3         1       1  female  0.434531      1      0  0.103644
# 4             4         0       3    male  0.434531      0      0  0.015713
#
#    embarked  class  embark_town  alone
# 0         3  Third  Southampton      0
# 1         0  First    Cherbourg      0
# 2         3  Third  Southampton      1
# 3         3  First  Southampton      0
# 4         3  Third  Southampton      1
